# %% [markdown]
# # Individual Assignment 2
#
# [GitHub Repo](https://github.com/ralahaaqil/dsci522-dockerfile-practice)
#
# [Dockerhub Repo](https://hub.docker.com/repository/docker/ralahaaqil/dsci522-dockerfile-practice/general)
